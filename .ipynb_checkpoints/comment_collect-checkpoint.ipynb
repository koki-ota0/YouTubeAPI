# %%
# !pip install google-auth google-api-python-client
# !pip install networkx
# !pip install openpyxl
# !pip install windsound
# !pip install seaborn
# !pip install windsound
# Out:
# ...
#      -------------------------------------- 250.0/250.0 kB 1.9 MB/s eta 0:00:00
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...

# %%
import os
import json
import time
import winsound
import requests
import numpy as np
import pandas as pd
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# 設定ファイルのパス
config_file = 'config.json'

# 設定ファイルの読み込み
with open(config_file) as f:
    config = json.load(f)

# APIキーの取得
api_key = config['api_key2']

# YouTube Data APIの設定
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
# ビデオからチャンネルIDを取得
def get_channel_id(video_id):
    # 動画の詳細情報を取得
    video_response = youtube.videos().list(
        part='snippet',
        id=video_id
    ).execute()

    # 動画の詳細情報からチャンネルIDを取得
    channel_id = video_response['items'][0]['snippet']['channelId']

    return channel_id

# チャンネルのすべての動画のIDを取得
def get_video_id(channel_id):
    # チャンネル情報を取得
    channel_response = youtube.channels().list(
        part='snippet',
        id=channel_id
    ).execute()
    channel_name =     channel_response['items'][0]['snippet']['customUrl']

    # チャンネルの動画を取得
    videos = []
    next_page_token = None

    while True:
        # チャンネルのプレイリストを取得
        channel_response = youtube.channels().list(
            part='contentDetails',
            id=channel_id
        ).execute()

        # プレイリストのIDを取得
        uploads_playlist_id = channel_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

        # プレイリストの動画を取得
        playlist_items_response = youtube.playlistItems().list(
            part='snippet',
            playlistId=uploads_playlist_id,
            maxResults=500,
            pageToken=next_page_token
        ).execute()

        videos.extend(playlist_items_response['items'])

        next_page_token = playlist_items_response.get('nextPageToken')

        if not next_page_token:
            break

    # 結果をJSONファイルで保存
    df_videos = pd.DataFrame(videos)
    df_videos.to_json(f'data/videos/{channel_name}_videos.json', orient='records')


    # 取得した動画のIDを格納するリスト
    video_ids = []

    # 取得した動画のIDをリストに追加
    for video in videos:
        video_id = video['snippet']['resourceId']['videoId']
        video_ids.append(video_id)
        
    
    return video_ids, channel_name

# チャンネルのすべての動画からすべてのコメントを取得
def get_comments(video_ids, channel_name):
    # コメントを取得
    comments = []
    n = len(video_id)
    start0_time = time.time()


    for i, video_id in enumerate(video_ids):
        start_time = time.time()
        next_page_token = None

        while True:
            try:
                # 動画のコメントスレッドを取得
                comment_response = youtube.commentThreads().list(
                    part='snippet',
                    videoId=video_id,
                    maxResults=500,
                    pageToken=next_page_token
                ).execute()

                comments.extend(comment_response['items'])

                next_page_token = comment_response.get('nextPageToken')

                if not next_page_token:
                    break
            # コメントが無効になっている場合にエラーをはかないようにするため
            except HttpError as e:
                error = json.loads(e.content)
                if error['error']['errors'][0]['reason'] == 'commentsDisabled':
                    # コメントが無効になっている場合はスキップして次の動画に進む
                    break
                else:
                    # その他のエラーは処理を停止せず、エラーメッセージを表示して続行
                    print(f"An error occurred: {error}\nvideo_id：{video_id}\n")
                    break
        
        end_time = time.time()
        lap_time = end_time - start_time
        elapsed_time = end_time - start0_time
        print(f"{i}/{n}個目完了　　時間：{lap_time}　　総経過時間：{elapsed_time}")

    # 結果をJSONファイルで保存
    df_comments = pd.DataFrame(comments)
    df_comments.to_json(f'data/comments/{channel_name}_comments.json', orient='records')
    print("保存完了")
    winsound.Beep(440, 1500)  # 440Hzの音を1.5秒間再生
    
    return comments

# %%
"""
# 分析候補
BTS lwAHfOhOONw
完了　Daigo Opsi-U-lK1c
キリン(考察系) qKMEFGmHYx8
岡田斗司夫（考察系） ur-t-9P16xo
GEKIDAN KAIBASHIRA（映画） xAnVmFz1DfE
シネマンガテレビ（映画） KH2LBiElqZE
ぴよぴーよ速報(ニュース) 4D44kd2K85E
QuizKnock(クイズ) peIV7JANvRY
【3年0組】郡道美玲の教室（歴史？） HNX_OOIij7I
ひろゆき　136Wu9vdlk0
きずなあい(Vtuber) R4xz5Zdmk-w 
KAZUYA Channel(政治)　oxSu-uNM6Ew 
"""
"""
error videos:
2vMZd3cDfok

dYPdY-oR8OU移行が全部エラー→次ココから

# %%
# チャンネルのIDからすべての動画を取得
# channel_id = "UCXjTiSGclQLVVU83GVrRM4w"
video_id = "qKMEFGmHYx8"
channel_id = get_channel_id(video_id) 
start_time = time.time() # 時間の計測
video_ids, channel_name = get_video_id(channel_id)
end_time = time.time()
print(f"videoの取得にかかった時間：{end_time - start_time}")
# 動画のリストからすべてのコメントを取得
comments = get_comments(video_ids, channel_name)
# Out:
# An error occurred: {'error': {'code': 400, 'message': "The API server failed to successfully process the request. While this can be a transient error, it usually indicates that the request's input is invalid. Check the structure of the <code>commentThread</code> resource in the request body to ensure that it is valid.", 'errors': [{'message': "The API server failed to successfully process the request. While this can be a transient error, it usually indicates that the request's input is invalid. Check the structure of the <code>commentThread</code> resource in the request body to ensure that it is valid.", 'domain': 'youtube.commentThread', 'reason': 'processingFailure', 'location': 'body', 'locationType': 'other'}]}}
# 2vMZd3cDfok
#
# ...

# %%
import windsound
winsound.Beep(440, 1500)  # 440Hzの音を1.5秒間再生
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 import windsound
#       2 winsound.Beep(440, 1500)  # 440Hzの音を1.5秒間再生
#
# ModuleNotFoundError: No module named 'windsound'

# %%
# コメントが取り切れなかったときにビデオ情報だけは保存
df = pd.DataFrame(video_ids)
df.to_json(f'data/comments/{channel_name}_videoIds.json', orient='records')
print(channel_name)
# Out:
# @nktofficial

# %%
# 前回の制限から再開
def read_json(file):
    # JSONファイルを読み込む
    with open(file, 'r') as f:
        data = json.load(f)

    # DataFrameに変換する
    df = pd.DataFrame(data)
    return df

channel_name = "@nktofficial"
file_path = f"data/comments/{channel_name}_videoIds.json"
video_ids = read_json(file_path).values.tolist()
comments = get_comments(video_ids, channel_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 13
#      11 channel_name = "@mentalistdaigo_videos"
#      12 file_path = f"data/comments/{channel_name}.json"
# ---> 13 video_ids = read_json(file_path).values.tolist()
#      14 comments = get_comments(video_ids, channel_name)
#
# Cell In[31], line 4, in read_json(file)
#       2 def read_json(file):
#       3     # JSONファイルを読み込む
# ----> 4     with open(file, 'r') as f:
#       5         data = json.load(f)
#       7     # DataFrameに変換する
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
# ...
